# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
group_0 = pd.read_excel('timetables/group_0.xlsx')
group_0
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45                                                 {}
# 1     8:50-9:35                                                 {}
# 2    9:40-10:45                                                 {}
# 3   10:50-11:35   {0: sala nr 6 | Lena Kowalska | Język angielski}
# 4   11:40-12:25  {0: sala nr 7 | Mateusz Kowalski | Język niemi...
# 5   12:30-13:15          {0: sala nr 7 | Katarzyna Mazur | Fizyka}
# 6   13:20-14:05     {0: sala nr 6 | Natalia Szymańska | Geografia}
# 7   14:10-14:55  {0: sala nr 8 | Zofia Wiśniewska | Wychowanie ...
# 8   15:00-15:45  {0: sala nr 3 | Zofia Wiśniewska | Wychowanie ...
# 9   15:50-16:35    {0: sala nr 4 | Paweł Lewandowski | Matematyka}
# 10  16:40-17:25                                                 {}
# 11  17:30-18:15                                                 {}
#
#                                                 Day 2  \
# ...

# %%
group_1 = pd.read_excel('timetables/group_1.xlsx')
group_1
# Out:
#           Hours                                            Day 1  \
# 0     8:00-8:45                                               {}
# 1     8:50-9:35   {0: sala nr 1 | Natalia Szymańska | Geografia}
# 2    9:40-10:45    {0: sala nr 8 | Dominik Kaczor | Informatyka}
# 3   10:50-11:35  {0: sala nr 9 | Paweł Lewandowski | Matematyka}
# 4   11:40-12:25    {0: sala nr 2 | Dominik Kaczor | Informatyka}
# 5   12:30-13:15  {0: sala nr 5 | Paweł Lewandowski | Matematyka}
# 6   13:20-14:05                                               {}
# 7   14:10-14:55                                               {}
# 8   15:00-15:45                                               {}
# 9   15:50-16:35                                               {}
# 10  16:40-17:25                                               {}
# 11  17:30-18:15                                               {}
#
#                                                Day 2  \
# 0      {0: sala nr 1 | Dominik Kaczor | Informatyka}
# ...

# %%
group_2 = pd.read_excel('timetables/group_2.xlsx')
group_2
# Out:
#           Hours                                             Day 1  \
# 0     8:00-8:45                                                {}
# 1     8:50-9:35                                                {}
# 2    9:40-10:45                                                {}
# 3   10:50-11:35                                                {}
# 4   11:40-12:25                                                {}
# 5   12:30-13:15        {0: sala nr 11 | Jan Nowak | Język polski}
# 6   13:20-14:05   {0: sala nr 9 | Paweł Lewandowski | Matematyka}
# 7   14:10-14:55   {0: sala nr 9 | Paweł Lewandowski | Matematyka}
# 8   15:00-15:45  {0: sala nr 10 | Paweł Lewandowski | Matematyka}
# 9   15:50-16:35      {0: sala nr 10 | Karolina Kamińska | Chemia}
# 10  16:40-17:25                                                {}
# 11  17:30-18:15                                                {}
#
#                                                 Day 2  \
# ...

# %%
group_3 = pd.read_excel('timetables/group_3.xlsx')
group_3
# Out:
#           Hours                                            Day 1  \
# 0     8:00-8:45                                               {}
# 1     8:50-9:35                                               {}
# 2    9:40-10:45                                               {}
# 3   10:50-11:35                                               {}
# 4   11:40-12:25                                               {}
# 5   12:30-13:15                                               {}
# 6   13:20-14:05                                               {}
# 7   14:10-14:55                                               {}
# 8   15:00-15:45   {0: sala nr 2 | Natalia Szymańska | Geografia}
# 9   15:50-16:35    {0: sala nr 3 | Dominik Kaczor | Informatyka}
# 10  16:40-17:25  {0: sala nr 1 | Paweł Lewandowski | Matematyka}
# 11  17:30-18:15  {0: sala nr 1 | Paweł Lewandowski | Matematyka}
#
#                                                 Day 2  \
# 0                                                  {}
# ...

# %%
group_4 = pd.read_excel('timetables/group_4.xlsx')
group_4
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45        {0: sala nr 4 | Karolina Kamińska | Chemia}
# 1     8:50-9:35  {0: sala nr 3 | Mateusz Kowalski | Język niemi...
# 2    9:40-10:45  {0: sala nr 10 | Zofia Wiśniewska | Wychowanie...
# 3   10:50-11:35         {0: sala nr 10 | Katarzyna Mazur | Fizyka}
# 4   11:40-12:25           {0: sala nr 4 | Piotr Wójcik | Biologia}
# 5   12:30-13:15   {0: sala nr 4 | Lena Kowalska | Język angielski}
# 6   13:20-14:05     {0: sala nr 11 | Dominik Kaczor | Informatyka}
# 7   14:10-14:55          {0: sala nr 5 | Jan Nowak | Język polski}
# 8   15:00-15:45                                                 {}
# 9   15:50-16:35                                                 {}
# 10  16:40-17:25                                                 {}
# 11  17:30-18:15                                                 {}
#
#                                                 Day 2  \
# ...

# %%
group_5 = pd.read_excel('timetables/group_5.xlsx')
group_5
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45                                                 {}
# 1     8:50-9:35                                                 {}
# 2    9:40-10:45                                                 {}
# 3   10:50-11:35      {0: sala nr 5 | Dominik Kaczor | Informatyka}
# 4   11:40-12:25    {0: sala nr 1 | Paweł Lewandowski | Matematyka}
# 5   12:30-13:15        {0: sala nr 2 | Karolina Kamińska | Chemia}
# 6   13:20-14:05          {0: sala nr 4 | Jan Nowak | Język polski}
# 7   14:10-14:55   {0: sala nr 3 | Lena Kowalska | Język angielski}
# 8   15:00-15:45          {0: sala nr 11 | Piotr Wójcik | Biologia}
# 9   15:50-16:35  {0: sala nr 9 | Zofia Wiśniewska | Wychowanie ...
# 10  16:40-17:25                                                 {}
# 11  17:30-18:15                                                 {}
#
#                                                 Day 2  \
# ...

# %%
group_6 = pd.read_excel('timetables/group_6.xlsx')
group_6
# Out:
#           Hours                                             Day 1  \
# 0     8:00-8:45     {0: sala nr 2 | Dominik Kaczor | Informatyka}
# 1     8:50-9:35    {0: sala nr 11 | Dominik Kaczor | Informatyka}
# 2    9:40-10:45  {0: sala nr 3 | Lena Kowalska | Język angielski}
# 3   10:50-11:35         {0: sala nr 4 | Jan Nowak | Język polski}
# 4   11:40-12:25                                                {}
# 5   12:30-13:15                                                {}
# 6   13:20-14:05                                                {}
# 7   14:10-14:55                                                {}
# 8   15:00-15:45                                                {}
# 9   15:50-16:35                                                {}
# 10  16:40-17:25                                                {}
# 11  17:30-18:15                                                {}
#
#                                                 Day 2  \
# ...

# %%
cost = pd.read_csv('charts_data/cost.csv')
plt.plot(cost)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.title("Chart of cost for algorithm")
plt.show()

# %%
best_cost = pd.read_csv('charts_data/best_cost.csv')
plt.plot(best_cost)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.title("Chart of best cost for algorithm")
plt.show()

# %%
temperature = pd.read_csv('charts_data/temperature.csv')
plt.plot(temperature)
plt.xlabel("Temperature iteration")
plt.ylabel("Temperature")
plt.title("Chart of temperature for algorithm")
plt.show()

# %%
logs = pd.read_csv('logs.csv')
logs.rename(columns = {'Unnamed: 0':'Parameters'}, inplace = True)
logs
# Out:
#                      Parameters  \
# 0               Max temperature
# 1               Min temperature
# 2                         K max
# 3                         Alpha
# 4                Max iterations
# 5     Neighbor with lesson swap
# 6              Cooling schedule
# 7         Initial solution cost
# 8            Best solution cost
# 9                    Iterations
# 10  Is best solution acceptable
# 11                      Runtime
#
#                                                 Value
# 0                                                 150
# 1                                                   5
# 2                                                  20
# 3                                               0.999
# 4                                          10000000.0
# 5                                                True
# 6   <function exponential_cooling_schedule at 0x00...
# 7                                            199309.5
# ...
