# %%
import pandas as pd
import matplotlib.pyplot as plt

hours = ['8:00-8:45', '8:50-9:35', '9:40-10:45', '10:50-11:35', '11:40-12:25', '12:30-13:15', '13:20-14:05', '14:10-14:55', '15:00-15:45', '15:50-16:35', '16:40-17:25', '17:30-18:15', '18:20-19:05', '19:10-19:55']

# %%
group_0 = pd.read_csv('timetables/group_0.csv')
group_0.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_0['Hours'] = hours
group_0
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45                                                 {}
# 1     8:50-9:35                                                 {}
# 2    9:40-10:45                                                 {}
# 3   10:50-11:35                                                 {}
# 4   11:40-12:25   {0: sala nr 4 | Lena Kowalska | Język angielski}
# 5   12:30-13:15        {0: sala nr 9 | Karolina Kamińska | Chemia}
# 6   13:20-14:05   {0: sala nr 9 | Lena Kowalska | Język angielski}
# 7   14:10-14:55                                                 {}
# 8   15:00-15:45                                                 {}
# 9   15:50-16:35  {0: sala nr 10 | Zofia Wiśniewska | Wychowanie...
# 10  16:40-17:25          {0: sala nr 5 | Jan Nowak | Język polski}
# 11  17:30-18:15          {0: sala nr 5 | Jan Nowak | Język polski}
# 12  18:20-19:05      {0: sala nr 6 | Dominik Kaczor | Informatyka}
# ...

# %%
group_1 = pd.read_csv('timetables/group_1.csv')
group_1.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_1['Hours'] = hours
group_1
# Out:
#           Hours                                        Day 1  \
# 0     8:00-8:45                                           {}
# 1     8:50-9:35                                           {}
# 2    9:40-10:45                                           {}
# 3   10:50-11:35                                           {}
# 4   11:40-12:25                                           {}
# 5   12:30-13:15                                           {}
# 6   13:20-14:05  {0: sala nr 8 | Karolina Kamińska | Chemia}
# 7   14:10-14:55     {0: sala nr 5 | Piotr Wójcik | Biologia}
# 8   15:00-15:45    {0: sala nr 4 | Katarzyna Mazur | Fizyka}
# 9   15:50-16:35    {0: sala nr 7 | Jan Nowak | Język polski}
# 10  16:40-17:25    {0: sala nr 3 | Katarzyna Mazur | Fizyka}
# 11  17:30-18:15                                           {}
# 12  18:20-19:05                                           {}
# 13  19:10-19:55                                           {}
#
# ...

# %%
group_2 = pd.read_csv('timetables/group_2.csv')
group_2.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_2['Hours'] = hours
group_2
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45    {0: sala nr 6 | Paweł Lewandowski | Matematyka}
# 1     8:50-9:35   {0: sala nr 7 | Lena Kowalska | Język angielski}
# 2    9:40-10:45      {0: sala nr 3 | Dominik Kaczor | Informatyka}
# 3   10:50-11:35      {0: sala nr 2 | Dominik Kaczor | Informatyka}
# 4   11:40-12:25  {0: sala nr 1 | Zofia Wiśniewska | Wychowanie ...
# 5   12:30-13:15          {0: sala nr 3 | Katarzyna Mazur | Fizyka}
# 6   13:20-14:05     {0: sala nr 1 | Natalia Szymańska | Geografia}
# 7   14:10-14:55        {0: sala nr 6 | Karolina Kamińska | Chemia}
# 8   15:00-15:45                                                 {}
# 9   15:50-16:35                                                 {}
# 10  16:40-17:25                                                 {}
# 11  17:30-18:15                                                 {}
# 12  18:20-19:05                                                 {}
# ...

# %%
group_3 = pd.read_csv('timetables/group_3.csv')
group_3.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_3['Hours'] = hours
group_3
# Out:
#           Hours                                             Day 1  \
# 0     8:00-8:45                                                {}
# 1     8:50-9:35                                                {}
# 2    9:40-10:45                                                {}
# 3   10:50-11:35                                                {}
# 4   11:40-12:25                                                {}
# 5   12:30-13:15                                                {}
# 6   13:20-14:05         {0: sala nr 4 | Jan Nowak | Język polski}
# 7   14:10-14:55  {0: sala nr 10 | Paweł Lewandowski | Matematyka}
# 8   15:00-15:45                                                {}
# 9   15:50-16:35  {0: sala nr 8 | Lena Kowalska | Język angielski}
# 10  16:40-17:25    {0: sala nr 10 | Dominik Kaczor | Informatyka}
# 11  17:30-18:15                                                {}
# 12  18:20-19:05                                                {}
# ...

# %%
group_4 = pd.read_csv('timetables/group_4.csv')
group_4.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_4['Hours'] = hours
group_4
# Out:
#           Hours                                             Day 1  \
# 0     8:00-8:45     {0: sala nr 1 | Dominik Kaczor | Informatyka}
# 1     8:50-9:35   {0: sala nr 3 | Paweł Lewandowski | Matematyka}
# 2    9:40-10:45  {0: sala nr 4 | Lena Kowalska | Język angielski}
# 3   10:50-11:35  {0: sala nr 10 | Paweł Lewandowski | Matematyka}
# 4   11:40-12:25         {0: sala nr 9 | Katarzyna Mazur | Fizyka}
# 5   12:30-13:15                                                {}
# 6   13:20-14:05                                                {}
# 7   14:10-14:55                                                {}
# 8   15:00-15:45                                                {}
# 9   15:50-16:35                                                {}
# 10  16:40-17:25                                                {}
# 11  17:30-18:15                                                {}
# 12  18:20-19:05                                                {}
# ...

# %%
group_5 = pd.read_csv('timetables/group_5.csv')
group_5.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_5['Hours'] = hours
group_5
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45                                                 {}
# 1     8:50-9:35                                                 {}
# 2    9:40-10:45                                                 {}
# 3   10:50-11:35                                                 {}
# 4   11:40-12:25                                                 {}
# 5   12:30-13:15      {0: sala nr 1 | Dominik Kaczor | Informatyka}
# 6   13:20-14:05  {0: sala nr 3 | Mateusz Kowalski | Język niemi...
# 7   14:10-14:55     {0: sala nr 1 | Natalia Szymańska | Geografia}
# 8   15:00-15:45    {0: sala nr 2 | Paweł Lewandowski | Matematyka}
# 9   15:50-16:35           {0: sala nr 5 | Piotr Wójcik | Biologia}
# 10  16:40-17:25        {0: sala nr 8 | Karolina Kamińska | Chemia}
# 11  17:30-18:15          {0: sala nr 6 | Katarzyna Mazur | Fizyka}
# 12  18:20-19:05          {0: sala nr 7 | Katarzyna Mazur | Fizyka}
# ...

# %%
group_6 = pd.read_csv('timetables/group_6.csv')
group_6.rename(columns = {'Unnamed: 0':'Hours'}, inplace = True)
group_6['Hours'] = hours
group_6
# Out:
#           Hours                                              Day 1  \
# 0     8:00-8:45   {0: sala nr 9 | Lena Kowalska | Język angielski}
# 1     8:50-9:35      {0: sala nr 9 | Dominik Kaczor | Informatyka}
# 2    9:40-10:45    {0: sala nr 1 | Paweł Lewandowski | Matematyka}
# 3   10:50-11:35   {0: sala nr 1 | Lena Kowalska | Język angielski}
# 4   11:40-12:25      {0: sala nr 2 | Dominik Kaczor | Informatyka}
# 5   12:30-13:15                                                 {}
# 6   13:20-14:05                                                 {}
# 7   14:10-14:55  {0: sala nr 9 | Mateusz Kowalski | Język niemi...
# 8   15:00-15:45        {0: sala nr 8 | Karolina Kamińska | Chemia}
# 9   15:50-16:35          {0: sala nr 9 | Katarzyna Mazur | Fizyka}
# 10  16:40-17:25                                                 {}
# 11  17:30-18:15                                                 {}
# 12  18:20-19:05         {0: sala nr 10 | Jan Nowak | Język polski}
# ...

# %%
cost = pd.read_csv('charts_data/cost.csv')
plt.plot(cost)
plt.xlabel("Iteration")
plt.ylabel("cost")
plt.title("Chart of cost for algorithm")
plt.show()

# %%
temperature = pd.read_csv('charts_data/temperature.csv')
plt.plot(temperature)
plt.xlabel("Iteration")
plt.ylabel("Temperature")
plt.title("Chart of temperature for algorithm")
plt.show()
